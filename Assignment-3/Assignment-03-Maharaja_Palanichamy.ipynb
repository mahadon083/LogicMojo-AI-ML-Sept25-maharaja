# %% [markdown]
# # Assignment-3
#
# This notebook contains the coding questions to test the proficiency in `Pandas` library in python.
#
# ### Date: 13th December, 2025
#
# ### Steps to solve and upload the assignment
#
# - Download the notebook in your local machine.
# - Solve the questions in the notebook and save it.
# - Rename the file as `Assignment-03-<your_name>_<your_surname>.ipynb`. For example if your name is Dipika Chopra then name the file as `Assignment-03-Dipika_Chopra.ipynb`.
# - Upload the solved notebook in your github repo under the folder **Assignment-3**.
# - Upload the solved notebook in the google drive location: https://drive.google.com/drive/folders/1mMtPeHCmsKQE8KxK_RmnFFkTPfo5RYNJ?usp=drive_link
# <h3><span style="color:red"> Deadline: 10th January, 2026 </span></h3>

# %% [markdown]
# Use the `population_by_county.csv` file in the folder to complete the tasks.
#
# **NOTE: TRY TO DO ALL THE TASKS IN ONE LINE OF PANDAS CODE.**

# %%
import pandas as pd

# %% [markdown]
# #### 1. Import pandas and read in the `population_by_county.csv` file into a dataframe called `pop`.

# %%
output = pd.read_csv("population_by_county.csv")

output
# Out:
#    Code            County           State  2010 Population  2017 Population  \
# 0     1  Abbeville County  South Carolina            25417            25999
# 1     2     Acadia Parish       Louisiana            61773            79909
# 2     3   Accomack County        Virginia            33164            66668
# 3     4        Ada County           Idaho           392365           418873
# 4     5      Adair County            Iowa             7682             9064
# 5     6      Adair County        Kentucky            18656            19876
# 6     7      Adair County        Missouri            25607            27980
# 7     8      Adair County        Oklahoma            22683            25898
#
#    2021 Population
# 0            24722
# 1            62590
# 2            32545
# 3           456849
# 4             7054
# 5            19485
# 6            25377
# 7            21909

# %% [markdown]
# #### 2. Show the head of the dataframe, Also show top 8 rows of the dataframe using head

# %%
print( "Top 8 rows of the dataset:" )
output.head(8)
# Out:
# Top 8 rows of the dataset:
#    Code            County            City  2020 Population  2021 Population
# 0     1  Abbeville County  South Carolina            25417            24722
# 1     2     Acadia Parish       Louisiana            61773            62590
# 2     3   Accomack County        Virginia            33164            32545
# 3     4        Ada County           Idaho           392365           456849
# 4     5      Adair County            Iowa             7682             7054
# 5     6      Adair County        Kentucky            18656            19485
# 6     7      Adair County        Missouri            25607            25377
# 7     8      Adair County        Oklahoma            22683            21909

# %% [markdown]
# #### 3. What are the column names?

# %%
print("Column names in the dataset:")
output.columns
# Out:
# Column names in the dataset:
# Index(['Code', 'County', 'City', '2020 Population', '2021 Population'], dtype='object')

# %% [markdown]
# #### 4. How many States are represented in this data set?
# <em>Note: the data includes the `District of Columbia`</em>

# %%
output['County'].nunique()
# Out:
# 5

# %% [markdown]
# #### 5. Get a list or array of all the states in the data set.

# %%
state_list = output['County'].unique()
state_list.sort()
state_list
# Out:
# array(['Abbeville County', 'Acadia Parish', 'Accomack County',
#        'Ada County', 'Adair County'], dtype=object)

# %% [markdown]
# #### 6. What are the five most common County names in the U.S.?

# %%
common_counties = output['County'].value_counts().head(5).rename("Count")
common_counties
# Out:
# County
# Adair County        4
# Abbeville County    1
# Acadia Parish       1
# Accomack County     1
# Ada County          1
# Name: Count, dtype: int64

# %% [markdown]
# #### 7. What are the top 5 most populated Counties according to the 2010 Census?

# %%
top5_2010 = output.sort_values(by='2010 Population', ascending=False).head(5)
top5_2010[['County', '2010 Population']]
# Out:
#              County  2010 Population
# 3        Ada County           392365
# 1     Acadia Parish            61773
# 2   Accomack County            33164
# 6      Adair County            25607
# 0  Abbeville County            25417

# %% [markdown]
# #### 8. What are the top 5 most populated States according to the 2010 Census?

# %%
output[['State','2010 Population']].groupby('State').sum().sort_values('2010 Population', ascending=False).head().index.to_list()
# Out:
# ['Idaho', 'Louisiana', 'Virginia', 'Missouri', 'South Carolina']

# %% [markdown]
# #### 9. How many Counties have 2010 populations greater than 1 million?

# %%
output[output['2010 Population'] > 1_000_000].shape[0]
# Out:
# 0

# %% [markdown]
# #### 10. How many Counties don't have the word "County" in their name?

# %%
output[~output['County'].str.contains('County')].shape[0]
# Out:
# 1

# %% [markdown]
# #### 11. Add a column that calculates the percent change between the 2010 Census and the 2017 Population Estimate

# %%
output['Percent Change'] = ((output['2017 Population'] - output['2010 Population']) / output['2010 Population']) * 100
output[['County', '2010 Population', '2017 Population', 'Percent Change']].head()
# Out:
#              County  2010 Population  2017 Population  Percent Change
# 0  Abbeville County            25417            25999        2.289806
# 1     Acadia Parish            61773            79909       29.359105
# 2   Accomack County            33164            66668      101.025208
# 3        Ada County           392365           418873        6.755954
# 4      Adair County             7682             9064       17.990107

# %% [markdown]
# #### 12. What States have the highest estimated percent change between the 2010 Census and the 2017 Population Estimate?
#
# **NOTE:** This will take several lines of code, as it requires a recalculation of Percent Change.

# %%
output[['State', 'Percent Change']].groupby('State').mean().sort_values('Percent Change', ascending=False).head()
# Out:
#            Percent Change
# State
# Virginia       101.025208
# Louisiana       29.359105
# Iowa            17.990107
# Oklahoma        14.173610
# Missouri         9.266997
